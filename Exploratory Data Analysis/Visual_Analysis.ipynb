# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/Certificates.pdf/Colab/Maternal Health Risk Data Set.csv')
data.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %% [markdown]
# Visual Analysis

# %%
#Univariate analysis
def num_plot(data,col):
   fig, ax = plt.subplots(1, 2,figsize=(12,4))
   sns.histplot(data=data, x=col, kde=True, ax=ax[0]) 
   sns.boxplot(data=data, x=col, ax=ax[1]) 
   ax[0].set_title(f"{col} Distribution Histogram") 
   ax[1].set_title(f"{col} Distribution Boxplot") 
   plt.show()
num_plot(data,'Age')

# %%
num_plot(data,'SystolicBP')

# %%
num_plot(data,'DiastolicBP')

# %%
num_plot(data,'BS')

# %%
num_plot(data,'BodyTemp')

# %%
num_plot(data,'HeartRate')

# %%
#Bivariate analysis
risk_order = ["low", "medium", "high"]  # Define the order of risk levels
p_colors = ["red", "green", "yellow"]  # Define the colors for each risk level

sns.histplot(data=data, x="Age",hue="RiskLevel",kde=True,palette=p_colors)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(data=data, x="SystolicBP",hue="RiskLevel",kde=True,palette=p_colors)
# Out:
# <Axes: xlabel='SystolicBP', ylabel='Count'>

# %%
sns.histplot(data=data, x="DiastolicBP",hue="RiskLevel",kde=True,palette=p_colors)
# Out:
# <Axes: xlabel='DiastolicBP', ylabel='Count'>

# %%
sns.histplot(data=data, x="BS",hue="RiskLevel",kde=True,palette=p_colors)
# Out:
# <Axes: xlabel='BS', ylabel='Count'>

# %%
sns.histplot(data=data, x="BodyTemp",hue="RiskLevel",kde=True,palette=p_colors)
# Out:
# <Axes: xlabel='BodyTemp', ylabel='Count'>

# %%
sns.histplot(data=data, x="HeartRate",hue="RiskLevel",kde=True,palette=p_colors)
# Out:
# <Axes: xlabel='HeartRate', ylabel='Count'>

# %%
#multivariate analysis
sns.scatterplot(data=data, x="Age",y="SystolicBP",hue="RiskLevel",palette=p_colors)
# Out:
# <Axes: xlabel='Age', ylabel='SystolicBP'>

# %%
sns.scatterplot(data=data, x="Age",y="DiastolicBP",hue="RiskLevel",palette=p_colors)
# Out:
# <Axes: xlabel='Age', ylabel='DiastolicBP'>

# %%
sns.scatterplot(data=data, x="Age",y="BS",hue="RiskLevel",palette=p_colors)
# Out:
# <Axes: xlabel='Age', ylabel='BS'>

# %%
sns.scatterplot(data=data, x="Age",y="BodyTemp",hue="RiskLevel",palette=p_colors)
# Out:
# <Axes: xlabel='Age', ylabel='BodyTemp'>

# %%
sns.scatterplot(data=data, x="Age",y="HeartRate",hue="RiskLevel",palette=p_colors)
# Out:
# <Axes: xlabel='Age', ylabel='HeartRate'>
